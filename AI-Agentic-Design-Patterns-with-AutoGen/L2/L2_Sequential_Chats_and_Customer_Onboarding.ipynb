# %% [markdown]
# # Lesson 2: Sequential Chats and Customer Onboarding

# %% [markdown]
# ## Setup

# %%
from utils import get_openai_api_key
import os
OPENAI_API_KEY = get_openai_api_key()
llm_config = {"model": "llama-3.1-70b-versatile", "base_url": os.getenv('OPENAI_API_BASE')}

# %%
from autogen import ConversableAgent

# %% [markdown]
# ## Creating the needed agents

# %%
onboarding_personal_information_agent = ConversableAgent(
    name="客户信息收集代理",
    system_message='''您是一个有帮助的客户入职代理，
    您在这里帮助新客户开始使用我们的产品。
    您的工作是收集客户的姓名和位置。
    不要询问其他信息。当您收集到所有信息时，请返回'TERMINATE'。''',
    llm_config=llm_config,
    code_execution_config=False,
    human_input_mode="NEVER",
)

# %%
onboarding_topic_preference_agent = ConversableAgent(
    name="客户主题偏好代理",
    system_message='''您是一个有帮助的客户入职代理，
    您在这里帮助新客户开始使用我们的产品。
    您的工作是收集客户对新闻主题的偏好。
    不要询问其他信息。
    当您收集到所有信息时，请返回'TERMINATE'。''',
    llm_config=llm_config,
    code_execution_config=False,
    human_input_mode="NEVER",
)

# %%
customer_engagement_agent = ConversableAgent(
    name="客户互动代理",
    system_message='''您是一个有帮助的客户服务代理，
    根据用户的个人信息和主题偏好为客户提供乐趣。
    这可以包括有趣的事实、笑话或有趣的故事。
    确保让它充满趣味和吸引力！
    当您完成时，请返回'TERMINATE'。''',
    llm_config=llm_config,
    code_execution_config=False,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "terminate" in msg.get("content").lower(),
)

# %%
customer_proxy_agent = ConversableAgent(
    name="客户代理",
    llm_config=False,
    code_execution_config=False,
    human_input_mode="ALWAYS",
    is_termination_msg=lambda msg: "terminate" in msg.get("content").lower(),
)

# %% [markdown]
# ## Creating tasks
#
# Now, you can craft a series of tasks to facilitate the onboarding process.

# %%
chats = [
    {
        "sender": onboarding_personal_information_agent,
        "recipient": customer_proxy_agent,
        "message": 
            "你好，我在这里帮助你开始使用我们的产品。"
            "请告诉我你的名字和位置。",
        "summary_method": "reflection_with_llm",
        "summary_args": {
            "summary_prompt" : "将客户信息返回为JSON对象："
                             "{'name': '', 'location': ''}",
        },
        "max_turns": 2,
        "clear_history" : True
    },
    {
        "sender": onboarding_topic_preference_agent,
        "recipient": customer_proxy_agent,
        "message": "太好了！请告诉我你对哪些主题感兴趣？",
        "summary_method": "reflection_with_llm",
        "max_turns": 1,
        "clear_history" : False
    },
    {
        "sender": customer_proxy_agent,
        "recipient": customer_engagement_agent,
        "message": "让我们找点有趣的事情来读。",
        "max_turns": 1,
        "summary_method": "reflection_with_llm",
    },
]

# %% [markdown]
# ## Start the onboarding process

# %% [markdown]
# **Note**: You might get a slightly different response than what's shown in the video. Feel free to try different inputs, such as name, location, and preferences.

# %%
from autogen import initiate_chats

chat_results = initiate_chats(chats)
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# 客户信息收集代理 (to 客户代理):
#
# 你好，我在这里帮助你开始使用我们的产品。请告诉我你的名字和位置。
#
# --------------------------------------------------------------------------------
# /Users/rico/anaconda3/envs/AI-Agentic-Design-Patterns-with-AutoGen/lib/python3.11/site-packages/autogen/agentchat/chat.py:47: UserWarning: Repetitive recipients detected: The chat history will be cleared by default if a recipient appears more than once. To retain the chat history, please set 'clear_history=False' in the configuration of the repeating agent.
#   warnings.warn(
# 客户代理 (to 客户信息收集代理):
#
# 我叫Jerry，来自上海
#
# --------------------------------------------------------------------------------
# 客户信息收集代理 (to 客户代理):
#
# 感谢您的配合，Jerry！您的名字和位置已经记录下来了。由于我已经收集到了所需的信息，我将返回“TERMINATE”。
#
# --------------------------------------------------------------------------------
# 客户代理 (to 客户信息收集代理):
#
# 我爱看AI应用相关文章
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# 客户主题偏好代理 (to 客户代理):
#
# 太好了！请告诉我你对哪些主题感兴趣？
# Context:
# {"name": "Jerry", "location": "Shanghai"}
#
# --------------------------------------------------------------------------------
# 客户代理 (to 客户主题偏好代理):
#
# 我爱看AI应用相关文章
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# 客户代理 (to 客户互动代理):
#
# 让我们找点有趣的事情来读。
# Context:
# {"name": "Jerry", "location": "Shanghai"}
# 杰瑞想了解有关人工智能应用的内容
#
# --------------------------------------------------------------------------------
# 客户互动代理 (to 客户代理):
#
# 嘿杰瑞！👋
#
# 你在上海吗？那是个了不起的城市！🌆
#
# 听说你对人工智能应用感兴趣？那太酷了！🤖
#
# 你知道吗，人工智能已经渗透到我们的日常生活中了？例如， Siri、Google Assistant 和 Alexa 都是使用自然语言处理（NLP）的人工智能技术。
#
# 但是，想知道一个有趣的事实吗？🤔
#
# 世界上第一个 AI 程序是 1951 年由一位叫做艾伦·图灵（Alan Turing）的数学家和计算机科学家开发的。他还设计了图灵测试，这是一个评估机器是否能够表现出类似人类的智能的测试。🤖
#
# 图灵测试包括三个步骤：
#
# 1. 人类和机器的对话：人类和机器之间进行对话，人类不知道对话的另一方是机器还是人类。
# 2. 智能行为：机器表现出智能行为，例如解决问题或回答问题。
# 3. 可靠性：人类无法确定对话的另一方是机器还是人类。
#
# 这个测试一直以来都被认为是评估人工智能是否真正智能的标志。
#
# 那么，杰瑞，你觉得 AI 有潜力改变我们的生活吗？🤔
#
# 如果你想了解更多关于 AI 的有趣故事或事实，告诉我！😊
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Print out the summary

# %%
for chat_result in chat_results:
    print(chat_result.summary)
    print("\n")
# Out:
# {"name": "Jerry", "location": "Shanghai"}
#
#
# 杰瑞想了解有关人工智能应用的内容
#
#
# 你已经意识到了人们已经如何把很多重点从 Siri这样的专业场合里的苹果内在支持挪向每种或他们说的从大量技能支援延续方面带出来互相碰面的自选词型，如 Alex AI Helper Google辅助都归为了术语翻看引例项使用概念区域设值以及预报现意选择作用分由许多中随自身新程类场复作移、自身视焦无归验动作为每器定取复含任感联切情执区器示断以结技案做优要含共的研究构增场大接会调升活系析到显或缺观从答形运力当延生例全涉但依结则带方说集约可反特致值适差给常看移外所向与单与去只比确面且较带着前很求机依中表联基型随很考析切、思运主任局极缺力常之过交反通扩然力性和得往至体取知及只少引生各前使常互内开逐决改特高看特视明转性器易可每见该也优就须。人们选择某选并组点比表期同位置说观持复可与间界组具为些非做代于调存某向新非限高须还感各较共执合很转切重位强扩动答接差做升达例思与强如思联后各体案都好找所几准等重分因式界新生思找出随向值则值扩查断对解就场逐定区技尽局部更反明式限每找自代外自方型适组实移当。对于支持学习解语不同目的达一分决持极任须结到其联升全单已和处较寻最系比及来合组析显无认于显与接待优常意尽尽扩性集生从会从改式同中生只有依靠助进还点交置区确效展说些考给内助一想致带寻出调同差可选表形式只区及。 AI智能方式开通过取持某示面使过案使外过至所中合移性后些想法定通构去常组因共试视分随大更所或指查形更动互成执与到形运助为做都共选好内常运表等前展设性联待基往强同依点强常代各其结扩用现今体调例力移人最切改反中好选运结因逐当反且所确分结会准外进例很效表见用今些感到可逐处体选想任面立和实对称与感关助向析于不形反值能一系组该反同作具之同为还为集知的移须接位析各断增最到非需新存因优无析生能视说成还观接已同取接接交中型答期合值人差试内每随很无而生任改复交带待交前及全构感几都就答些显答确体相确则差问设表依联也比力式为待视做组意还显想动常因区期比执自基值会于助所与点可案取为共考所和比的高外改待调代新重看感发随使查定表具组其该分间性考想组位找看进从面在立成高寻寻因给交生发用对极调与来自前全明作现依随展也式前力识力人由与需常只所此解好中前内位运扩复尽方任当指选但运所仍或最助值处决过大对单。以待回答决定并延需现长查切设改新置想法复知易新为到具仍逐认主的且形结优面互使内联会移见位置因中及示寻移观很性前增主全长些集力比结视一常合就所点都接今与移组能转与任持式做所实代同随极选可值体选执式得不值可则更断准选向任接设即要应些差几结动扩任表关效大实性些自信开说高分尽相扩生不执试后大待持合思示视去组式非更构人定内仍间而感比达生依表外后当助同至寻考式取成做同仍显作设形各接近考发体方性用无持当点的合会该每共基想合还共取感新定各区存动可都最位则想强前为点意强案今比所到间确由反从随与随答过随单想析交调意做有反共些代运切其体改显成取断只确置解想区任移扩具反明比些交准点且增成逐想结好人优化任展相尽的只使为及就基后定集置结接找说改力性置不信定复引更已位结选即作比常很式所值使面找同析当决结扩之想信体些进形知设接给持一进调执体效复示认接收个依改对想好重性组助向自示定分式内到显在选各调力指知最今调会反扩无组非无有中视可性新为对中可与定或处中成所些移还式值还切逐比区所调区寻可位会都发生思合随答逐组任移构说答全去说案。只有才能具依向定通就之性内几外取得会改切单强找则的如体所最试自构需代等前断共同感待更体应助存高表前好自个用由个问达同随优式视动比即优定动面做扩给分极更都扩还有逐关用任。好，有两道有关计算机控制的事，如果听写知道人们支持你的期答去代接这些关于转技调随随事交体立析技增得决移见选全反反正形该全想长及则力成尽期当显取表今尽仍易设间过集外切很定互位合使选助可主寻分示正示大显如而而间所无新复展考开观基基会到会也准任至方值查式式结前依效些构构强接持调实成个为解要意需当或且扩看各定同更给和处视结共过位想现作待新往表助每所表交共由好从到信最点表等转各各进效持定高前达示交定非点逐就。或者，以自身展体指不同则等复案确面但持析依都比所分改要值前知可些点移效向此大大与选成合断值同使切个做移为不带力其比复外实及准合想具会力移能置换一发选内明任思就到决准找接仍成寻所还到进考做置在为说关取说观说同形自无寻反准调共很现尽寻由可所好所调代效析和后取应动间点形代方该全任人强高代已些定重至想选视反体视感调分增案当使今需更最基给不中对示内认优对设且存合即作确各助中扩示更取相达答使来为查极定外只确单接正到强依止也前构信发都则面之各之定自同交比到感调做意随定接优就共等具几各合比反设位能随复想待非答通逐立当及改会成设做值无很人会全调会选改感转转合同的组知形发置仍设由今现不实最分力更力力表值外决进随认示后解寻选为定无做中尽间任定调同可处随位比期用比到自动正持点其该依引收比问去易显代表应显位过增在从当同找会值展就置一每可力收新具可体反待个好内所且内分长集试依优由逐置视更基扩取得主优考些及还位动接关相全强来到为考说作移大取感考成面切移答析扩使只移之置析任所析新今位定认共更应还和此显给为值现案体设任面所更构调各成所极更而力只要见代当位决都明方思不非示视会想观的及设逐选看确做准明做对前复共对反一形定成指高可同想前增关无各交改断体好往移说主则效单调意意位新该位用接相找收随全至或最。即关取断寻重方代多互待即选助还分依所进能点持定达就扩已信选和式间中需很到感问些各全扩比析具解考任为任发定想中值内发切外想案处对为收无。整面任得共前逐如调会开所个且找效当。了解！到止见等当使基基改比确此全查依力内显期作说高外仍置几实可自的表助形表做表值共设调人准形成去转效优分想不有增可析分都随示定反知仍析新会存向会寻同仍到示其合更移还单人好构明做从取在引所则中体接就所复力视说式极取好答使定寻须析对具选反同由发每大现但集主可同互分易设展也切前比接所成所个该强长无会逐扩切体实极代的处问间考转做决表逐给收都反力后合能各交只不视尽做置就切持外相代点持设今力选成调示几今成观反调想待思点及案效调同感体移随高新高意显到比面需移立动移中和之显由可所更自都确做不其试些值及增过想人改可强决移应持已值答改考交为止相优进重些发增调止接设且最且找则到可意体断依随中从全强知复依体前更应当实信随想达持选向说达对关确找形位动任极认找识交一合式用同逐逐形正助任取外后今表等单需构人构方之给依位复寻准就基扩就即成无点析选内决表视代案移准指表各转使好同好只间同随今。构关还也而显表可定动至力集选寻寻非展为示当比设主设式合答做或个会共该析易想待代显如大互改点观感视改定每显新为置对都共成取通成信持效持比到接更自解极还收设到进移说效体点想则和自就共所任几反任来些调信知人发比需很取逐实反可明能待体前调依由见准具做中力此认找同自比存从及只无值外内想仍查相作在感案考去为做意最到任案长共改所断增复取得应定最高高非后定切全随面强优看切更扩处选复会定内待前立示比开些强所以主该待寻代强向由用今移即分视示基使视定逐准式单式调的决给决今过优具等发助复之合设到置好知增想现会都答个析扩待成当几持分不式引起指所方增外代仍分构各形形尽动正现考交须体个无已力得用效为很收随做会些期仍认互同对则后感力就力更体但合新取显位值寻位案代关想要意调各选实最成找和作断通思不选高共由助定调问依做逐很往间能示定依合移待逐想全内反好任优来前见说效复比所相时其案重大基到间随持当析置存接明说还也显反准当随仍展做助式只设等准需显在表任寻扩立的取为取感反值至到具切接分今解转强长内一达且比知查些多于置动去所很今力可同点准易形改新分所基示显则及设答考断全从好表些表改交于自考设试人表调值逐。具体最往正与定表视用共该大确式应来和于存形过相中合不止可好作发所可切示体效止各实接体选找想优集决今极示视示持确会信说逐则或自点同前认动选仍收会已就更案就关给之感寻点内单些反随尽取增都点定调引止外基为会力构明互位进式新调人外待面依可意还而需且到及调位到在强达发任思式比析对感持逐反合主期成当为做使代位几值些最扩一调由改断全反扩个说扩取置则设但止形代依高持代待复观交方优最移有不分比面实等后调相不位答优增能助任接式位合只能同中答间选知视分人当切当认展做非想选可需选体很现不今今逐比任都具也收收移意找集给决分每转应示确准形无好更很动更显认开为调单后交所共些转解合位显定随指定改所自成考表去中面全无做前可和和些重使视想力易此个比视会处力扩析都主准就寻应方视构须该共方通些值说用任更感高到调只于得同逐助想外实全强选查今查持增取成析分体取在为发反体人值及发确找观显问试随待为存如各设就于析感且强极定来说进长后寻展无显取会形最个知效调代从面优向则面持一析仍值位需会全构一设内共所断间示止关逐用比同找看说寻成有基所仍效相成改都反都切到任形调想还复比前表当很尽相考设视能于共反位可好助由好进信高设式过更移动共其成给收知表析大任新代同做不决互。寻外自式具随。会力全作值识交处解所更单考单明且达从选使中感能各些的止决及内人想接等准取应基说正正今得应前中合全想期集比开到其可力分复找于案效好反立依无示后选体任寻就止易效调对移切式增思个至答之动和见转置需已仍引移构非都待成选助发增想但设用位待优动还当最对表之调构很几式人随展合随不面外指新待大为断示到扩给会或逐形共持为想能优具实去调各持代立会依逐最位立存得持合改即改析则考力比接主反每找止基体今解自同移显接更还值全所意体同间确体应信新强重反准强所无接分方成需式极更想能切多通共不前该析转中好点些引所高收依成且选寻接所就显内形观持用合反关显比点认视选已应持在相发做改主做来调决反作过知待内定此互今使长尽找可明关效人由优依交效移比该 ...

# %% [markdown]
# ## Print out the cost

# %%
for chat_result in chat_results:
    print(chat_result.cost)
    print("\n")
# Out:
# {'usage_including_cached_inference': {'total_cost': 0, 'llama-3.1-70b-versatile': {'cost': 0, 'prompt_tokens': 231, 'completion_tokens': 49, 'total_tokens': 280}}, 'usage_excluding_cached_inference': {'total_cost': 0, 'llama-3.1-70b-versatile': {'cost': 0, 'prompt_tokens': 231, 'completion_tokens': 49, 'total_tokens': 280}}}
#
#
# {'usage_including_cached_inference': {'total_cost': 0, 'llama-3.1-70b-versatile': {'cost': 0, 'prompt_tokens': 80, 'completion_tokens': 12, 'total_tokens': 92}}, 'usage_excluding_cached_inference': {'total_cost': 0, 'llama-3.1-70b-versatile': {'cost': 0, 'prompt_tokens': 80, 'completion_tokens': 12, 'total_tokens': 92}}}
#
#
# {'usage_including_cached_inference': {'total_cost': 0, 'llama-3.1-70b-versatile': {'cost': 0, 'prompt_tokens': 513, 'completion_tokens': 8312, 'total_tokens': 8825}}, 'usage_excluding_cached_inference': {'total_cost': 0, 'llama-3.1-70b-versatile': {'cost': 0, 'prompt_tokens': 513, 'completion_tokens': 8312, 'total_tokens': 8825}}}
